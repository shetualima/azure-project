# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\alima\appdata\local\programs\python\python310\lib\site-packages (2.2.3)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alima\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alima\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\alima\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alima\appdata\roaming\python\python310\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\alima\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\alima\Desktop\project File\Heart attack prediction.csv")

# %%
df.head()
# Out:
#    age  Gender  sex  cp Resting blood pressure(trestbps) Cholesterol(mg/dl)  \
# 0   28    Male    1   2                              130                132
# 1   29    Male    1   2                              120                243
# 2   29    Male    1   2                              140                  ?
# 3   30  Female    0   1                              170                237
# 4   31  Female    0   2                              100                219
#
#   fbs restecg thalach exang  oldpeak slope ca thal  num (Target)
# 0   0       2     185     0      0.0     ?  ?    ?           0.0
# 1   0       0     160     0      0.0     ?  ?    ?           0.0
# 2   0       0     170     0      0.0     ?  ?    ?           0.0
# 3   0       1     170     0      0.0     ?  ?    6           0.0
# 4   0       1     150     0      0.0     ?  ?    ?           0.0

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\alima\appdata\local\programs\python\python310\lib\site-packages (0.13.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\alima\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\alima\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\alima\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\alima\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: pillow>=8 in c:\users\alima\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alima\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\alima\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\alima\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\alima\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\alima\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\alima\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alima\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alima\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\alima\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df.describe()
# Out:
#               age         sex          cp     oldpeak  num (Target)
# count  294.000000  294.000000  294.000000  294.000000    293.000000
# mean    47.826531    0.734694    3.411565    0.589456      0.358362
# std      7.811812    0.486353    7.470351    0.912068      0.480340
# min     28.000000    0.000000    1.000000    0.000000      0.000000
# 25%     42.000000    0.000000    2.000000    0.000000      0.000000
# 50%     49.000000    1.000000    3.000000    0.000000      0.000000
# 75%     54.000000    1.000000    4.000000    1.000000      1.000000
# max     66.000000    4.000000  130.000000    5.000000      1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294 entries, 0 to 293
# Data columns (total 15 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   age                               294 non-null    int64
#  1   Gender                            294 non-null    object
#  2   sex                               294 non-null    int64
#  3   cp                                294 non-null    int64
#  4   Resting blood pressure(trestbps)  294 non-null    object
#  5   Cholesterol(mg/dl)                294 non-null    object
#  6   fbs                               294 non-null    object
#  7   restecg                           294 non-null    object
#  8   thalach                           294 non-null    object
#  9   exang                             294 non-null    object
#  10  oldpeak                           294 non-null    float64
#  11  slope                             294 non-null    object
#  12  ca                                294 non-null    object
#  13  thal                              294 non-null    object
#  14  num (Target)                      293 non-null    float64
# dtypes: float64(2), int64(3), object(10)
# memory usage: 34.6+ KB

# %%
print(df['fbs'].value_counts(dropna=False))  # Include NaN counts
# Out:
# fbs
# 0    265
# 1     21
# ?      8
# Name: count, dtype: int64

# %%
# Handle non-numeric values (e.g., drop rows with NaN)
df.dropna(subset=['fbs'], inplace=True) 

# Convert to integer (if applicable)
df['fbs'] = pd.to_numeric(df['fbs'], errors='coerce') 

# Print data types
print(df.dtypes)
# Out:
# age                                   int64
# Gender                               object
# sex                                   int64
# cp                                    int64
# Resting blood pressure(trestbps)     object
# Cholesterol(mg/dl)                   object
# fbs                                 float64
# restecg                              object
# thalach                              object
# exang                                object
# oldpeak                             float64
# slope                                object
# ca                                   object
# thal                                 object
# num (Target)                        float64
# dtype: object

# %%
print(df.head()) 
print(df.tail())
# Out:
#    age  Gender  sex  cp Resting blood pressure(trestbps) Cholesterol(mg/dl)  \
# 0   28    Male    1   2                              130                132
# 1   29    Male    1   2                              120                243
# 2   29    Male    1   2                              140                  ?
# 3   30  Female    0   1                              170                237
# 4   31  Female    0   2                              100                219
#
#    fbs restecg thalach exang  oldpeak slope ca thal  num (Target)
# 0  0.0       2     185     0      0.0     ?  ?    ?           0.0
# 1  0.0       0     160     0      0.0     ?  ?    ?           0.0
# 2  0.0       0     170     0      0.0     ?  ?    ?           0.0
# 3  0.0       1     170     0      0.0     ?  ?    6           0.0
# 4  0.0       1     150     0      0.0     ?  ?    ?           0.0
#      age  Gender  sex   cp Resting blood pressure(trestbps)  \
# 289   52  Female    1    4                              160
# 290   54    Male    0    3                              130
# 291   56  Female    1    4                              155
# 292   58    Male    0    2                              180
# 293   65    Male    4  130                              275
#
#     Cholesterol(mg/dl)  fbs restecg thalach exang  oldpeak slope ca thal  \
# 289                331  0.0       0      94     1      2.5     ?  ?    ?
# 290                294  0.0       1     100     1      0.0     2  ?    ?
# 291                342  1.0       0     150     1      3.0     2  ?    ?
# 292                393  0.0       0     110     1      1.0     2  ?    7
# 293                  0  1.0     115       1     1      2.0     ?  ?    1
#
#      num (Target)
# 289           1.0
# 290           1.0
# 291           1.0
# 292           1.0
# 293           NaN

# %%
# Check for column names
print(list(df.columns))

# Assuming 'column' is a typo and the actual column name is 'fbs'
df['fbs'].fillna(df['fbs'].mean(), inplace=True)  # Impute missing values in 'fbs'
# OR
#
# Out:
# ['age', 'Gender', 'sex', 'cp', 'Resting blood pressure(trestbps)', 'Cholesterol(mg/dl)', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num (Target)']

# %%
print(list(df.columns))
# Out:
# ['age', 'Gender', 'sex', 'cp', 'Resting blood pressure(trestbps)', 'Cholesterol(mg/dl)', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num (Target)']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a function to generate a scatter plot
def create_scatter_plot(df, x_column, y_column, title, x_label, y_label):
    """Creates and displays a scatter plot."""
    plt.figure(figsize=(10, 6))  # Set the figure size for better visibility
    plt.scatter(df[x_column], df[y_column], alpha=0.6, color='skyblue') # alpha for point transparency
    plt.title(title, fontsize=14)  # Set plot title
    plt.xlabel(x_label, fontsize=12)  # Set x-axis label
    plt.ylabel(y_label, fontsize=12)  # Set y-axis label
    plt.grid(True, linestyle='--')  # Add a grid for easier reading
    plt.tight_layout() # Adjust the layout so that elements do not overlap
    plt.show()


# Create scatter plot for 'chol' vs. 'thalach'
create_scatter_plot(df,
                    'Cholesterol(mg/dl)',
                    'thalach',
                    'Scatter Plot of Cholesterol vs. Max Heart Rate',
                    'Cholesterol Level',
                    'Max Heart Rate Achieved')


# Create scatter plot for 'age' vs. 'thalach'
create_scatter_plot(df,
                    'age',
                    'thalach',
                    'Scatter Plot of Age vs. Max Heart Rate',
                    'Age',
                    'Max Heart Rate Achieved')

# %%
# Handle non-numeric values (replace '?' with NaN)
df[['Cholesterol(mg/dl)', 'Resting blood pressure(trestbps)']] = df[['Cholesterol(mg/dl)', 'Resting blood pressure(trestbps)']].replace('?', np.nan)

# Convert to numeric (if applicable, errors will be converted to NaN)
df['Cholesterol(mg/dl)'] = pd.to_numeric(df['Cholesterol(mg/dl)'], errors='coerce')
df['Resting blood pressure(trestbps)'] = pd.to_numeric(df['Resting blood pressure(trestbps)'], errors='coerce')

# Check for and handle missing values 
if 'thalach' in df.columns:
    df.dropna(subset=['Cholesterol(mg/dl)', 'Resting blood pressure(trestbps)', 'thalach'], inplace=True)
else:
    print("Warning: 'thalach' column not found in df. Skipping dropping rows based on 'thalach'.")

# Select the relevant columns for the correlation matrix
selected_columns = ['age', 'Cholesterol(mg/dl)', 'Resting blood pressure(trestbps)']
correlation_matrix = df[selected_columns].corr()

# Create a heatmap to visualize the correlations
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix: Age, Cholesterol, and Blood Pressure')
plt.show()

# %%
gender_colors = {'Male': 'skyblue', 'Female': 'coral'}  # Define your colors here

def get_color(gender):
         return gender_colors.get(gender, 'gray')  # Return default color for unknown genders

    # Create the FacetGrid
g = sns.FacetGrid(df, col='Gender', height=4, aspect=1.2)

    # Get the color list and iterate through each subplot to create different colors
for ax, gender in zip(g.axes.flat, df['Gender'].unique()):
        sns.histplot(x='age', kde=True, bins=20, data=df[df['Gender'] == gender], color=get_color(gender), ax = ax)

    # Customize the plot
g.fig.suptitle('Age Distribution by Gender', y=1.1)  #Adjust title position to prevent overlap
    #g.fig.subplots_adjust(top=0.8) #No need to use subplots_adjust, as y in suptitle controls the title position.
g.set_xticklabels(rotation=45)
g.set_titles(col_template = "{col_name}") #Adjust column titles
plt.tight_layout()
plt.show()

# %%
# Box plot for 'cholesterol' by 'sex'
sns.boxplot(x='sex', y='Cholesterol(mg/dl)', data=df)
plt.title('Cholesterol Levels by Sex')
plt.xlabel('Sex')
plt.ylabel('Cholesterol')
plt.show()

# Bar plot for 'fbs' (fasting blood sugar)
sns.countplot(x='fbs', data=df)
plt.title('Distribution of Fasting Blood Sugar')
plt.xlabel('Fasting Blood Sugar')
plt.ylabel('Count')
plt.show()

# %%
# Create age groups (example: categorize age into decades)
df['age_group'] = pd.cut(df['age'], bins=[20, 30, 40, 50, 60, 70, 80], labels=['20s', '30s', '40s', '50s', '60s', '70s+'])

# Box plot for 'cholesterol' by age group
sns.boxplot(x='age_group', y='Cholesterol(mg/dl)', data=df)
plt.title('Cholesterol Levels by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Cholesterol')
plt.show()

# %%
# Calculate heart attack risk by age group and gender (assuming 'num_events' is the column)
heart_attack_risk_by_age_gender = df.groupby(['age_group', 'sex'])['num (Target)'].mean()

# Visualize heart attack risk by age group and gender
plt.figure(figsize=(10, 6))
heart_attack_risk_by_age_gender.unstack().plot(kind='bar')
plt.title('Heart Attack Risk by Age Group and Gender')
plt.xlabel('Age Group')
plt.ylabel('Heart Attack Risk')
plt.legend(['Female', 'Male'])
plt.show()

# %%
# Bar plot for 'sex' 
if 'sex' in df.columns:
    sns.countplot(x='sex', data=df)
    plt.title('Distribution of Sex')
    plt.xlabel('Sex')
    plt.ylabel('Count')
    plt.show()

# %%
# 1. Average Age
average_age = df['age'].mean()
print(f"Average Age: {average_age:.2f}")
# Out:
# Average Age: 47.78

# %%
# 2. Gender Distribution 
gender_counts = df['sex'].value_counts()
print("\nGender Distribution:")
print(gender_counts)
# Out:
# Gender Distribution:
# sex
# 1    196
# 0     73
# 4      1
# Name: count, dtype: int64

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\alima\appdata\local\programs\python\python310\lib\site-packages (5.24.1)
# Requirement already satisfied: packaging in c:\users\alima\appdata\roaming\python\python310\site-packages (from plotly) (24.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\alima\appdata\local\programs\python\python310\lib\site-packages (from plotly) (9.0.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import plotly.express as px

# (1 for heart disease, 0 for no heart disease)
fig = px.histogram(df, x="age", color="num (Target)", 
                title="Age Distribution by Heart Disease Status",
                labels={"age": "Age", "target": "Heart Disease (1=Yes, 0=No)"})
fig.show()
